# %%
# greetings *****
print ("SELAMAT DATANG!")
print ("")
print (" ---Menu--- ")
print ("1. Daftar Kontak")
print ("2. Tambah Kontak")
print ("3. Keluar")
print ("")


# if, elif, else
x = int (input("Pilih menu: "))
print ("")
menu = int(x)

if menu == 1:
  print ("Daftar Kontak: ") and print (y)
elif menu == 2:
  print ("Tambah Kontak") and print (z)
else:
  print ("Keluar")

print ("")

# loop through dictionary element in python
# dictionary

pelanggan = {
    "nama": "fawwaz",
    "umur": 21,
   }

pelanggan_2 = {
    "nama": "andi",
    "umur": 18,
}

#list of dictionary
daftar_pelanggan = []
daftar_pelanggan.append(pelanggan)
daftar_pelanggan.append(pelanggan_2)

for pelanggan in daftar_pelanggan:
  print("Nama: {}".format(pelanggan["nama"]))
  print("Umur: {}".format(pelanggan["umur"])) 
  print("")

# tambah pelanggan
count = int (input("Tambah data pelanggan: "))

nama_pelanggan = []
umur_pelanggan = []

print("")
print("Masukkan data pelanggan")
print("")

for i in range (count):
  print ("Pelanggan ke {}". format (i+1))
  nama = input ("Nama: ")
  umur = int(input("Umur: "))

  nama_pelanggan.append(nama)
  umur_pelanggan.append(umur)

print("")
print("Pelanggan baru yang terdaftar adalah: ")
print("")
for i in range(len(nama_pelanggan)):
  print("Pelanggan {} berumur {}". format (nama_pelanggan [i], umur_pelanggan [i]))
# Out:
# SELAMAT DATANG!
#
#  ---Menu---
# 1. Daftar Kontak
# 2. Tambah Kontak
# 3. Keluar
#
# Pilih menu: 2
#
# Tambah Kontak
#
# Nama: fawwaz
# Umur: 21
#
# Nama: andi
# Umur: 18
#
# Tambah data pelanggan: 2
#
# Masukkan data pelanggan
#
# Pelanggan ke 1
# Nama: hui
# Umur: 67
# Pelanggan ke 2
# Nama: gye
# Umur: 56
#
# Pelanggan baru yang terdaftar adalah:
#
# Pelanggan hui berumur 67
# Pelanggan gye berumur 56

# %% [markdown]
# **Kenapa tidak bisa diganti menjadi kontak??**

# %%
# greetings *****
print ("SELAMAT DATANG!")
print ("")
print (" ---Menu--- ")
print ("1. Daftar Kontak")
print ("2. Tambah Kontak")
print ("3. Keluar")
print ("")


# if, elif, else
x = int (input("Pilih menu: "))
menu = int(x)

if menu == 1:
  print ("Daftar Kontak: ")
elif menu == 2:
  print ("Tambah Kontak")
else:
  print ("Keluar")

# loop through dictionary element in python
# dictionary

pelanggan = {
    "nama": "fawwaz",
    #"umur": 21,
    "kontak": "08012345678"
}

pelanggan_2 = {
    "nama": "andi",
    #"umur": 18,
    "kontak": "08045678910"
}

# print("Nama: {}".format(pelanggan["nama"]))
# print("Umur: {}".format(pelanggan["umur"]))

# change value of dictionary
# pelanggan["umur"] = 22

# print("Nama: {}".format(pelanggan["nama"]))
# print("Umur: {}".format(pelanggan["umur"]))

# loop through dictionary
#for x in pelanggan:
#  print(x)
#  print(pelanggan[x])
#  print(pelanggan_2[x])

#list of dictionary
daftar_pelanggan = []
daftar_pelanggan.append(pelanggan)
daftar_pelanggan.append(pelanggan_2)

for pelanggan in daftar_pelanggan:
  print("Nama: {}".format(pelanggan["nama"]))
  #print("Umur: {}".format(pelanggan["umur"]))
  print("No. Telepon": {}. format(pelanggan["kontak"]))
# Out:
#   File "<ipython-input-13-4a989b79a970>", line 60
#     print("No. Telepon": {}. format(pelanggan["kontak"]))
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Kenapa tidak dapat ditambah kontak???**

# %%
# greetings *****
print ("SELAMAT DATANG!")
print ("")
print (" ---Menu--- ")
print ("1. Daftar Kontak")
print ("2. Tambah Kontak")
print ("3. Keluar")
print ("")


# if, elif, else
x = int (input("Pilih menu: "))
menu = int(x)

if menu == 1:
  print ("Daftar Kontak: ")
elif menu == 2:
  print ("Tambah Kontak")
else:
  print ("Keluar")

# loop through dictionary element in python
# dictionary

pelanggan = {
    "nama": "fawwaz",
    "umur": 21,
    #"kontak": "08012345678"
}

pelanggan_2 = {
    "nama": "andi",
    "umur": 18,
    #"kontak": "08045678910"
}

# print("Nama: {}".format(pelanggan["nama"]))
# print("Umur: {}".format(pelanggan["umur"]))

# change value of dictionary
# pelanggan["umur"] = 22

# print("Nama: {}".format(pelanggan["nama"]))
# print("Umur: {}".format(pelanggan["umur"]))

# loop through dictionary
#for x in pelanggan:
#  print(x)
#  print(pelanggan[x])
#  print(pelanggan_2[x])

#list of dictionary
daftar_pelanggan = []
daftar_pelanggan.append(pelanggan)
daftar_pelanggan.append(pelanggan_2)

for pelanggan in daftar_pelanggan:
  print("Nama: {}".format(pelanggan["nama"]))
  print("Umur: {}".format(pelanggan["umur"]))
  #print("No. Telepon": {}. format(pelanggan["kontak"]))
# Out:
# SELAMAT DATANG!
#
#  ---Menu---
# 1. Daftar Kontak
# 2. Tambah Kontak
# 3. Keluar
#
# Pilih menu: 3
# Keluar
# Nama: fawwaz
# Umur: 21
# Nama: andi
# Umur: 18
